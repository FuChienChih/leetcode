# %% [markdown]
# Given an integer x, return true if x is palindrome integer.
#
# An integer is a palindrome when it reads the same backward as forward.
#
# For example, 121 is a palindrome while 123 is not.

# %% [markdown]
# 解題思路：
#
# 存成list判斷反轉後是否相等
#
# 反轉：reverse()

# %%
class Solution:
    def isPalindrome(self, x: int):
        Palindrome = list(f'{x}')
        Palindrome.reverse()
        if Palindrome == list(f'{x}'):
            return True
        else :
            return False

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-01-17%20%E4%B8%8B%E5%8D%884.07.10.png](attachment:%E6%88%AA%E5%9C%96%202022-01-17%20%E4%B8%8B%E5%8D%884.07.10.png)
